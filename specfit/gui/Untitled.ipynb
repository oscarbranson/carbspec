# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from dummyInstruments import Spectrometer
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
spec = Spectrometer()

spec.light_off()
dark = spec.read()

spec.light_on()
spec.sample_absent()
spec.channel_0()
sc0 = spec.read()
spec.channel_1()
sc1 = spec.read()

sf = sc1 / sc0

spec.sample_present()

spec.channel_0()
c0 = spec.read()

spec.channel_1()
c1 = spec.read()

# %%
plt.plot(spec.wv, spec.light_only)

# %%
plt.plot()
plt.plot(c1 - dark)

# %%
Abs = np.log10((c0 * sf - dark) / (c1 - dark))

# %%
plt.plot(spec.wv, Abs)
plt.plot(spec.wv, spec.Abs)

# %%
plt.plot(spec.wv, sc0 * sf)
plt.plot(spec.wv, sc1)

# %%
spec.channel_0()
